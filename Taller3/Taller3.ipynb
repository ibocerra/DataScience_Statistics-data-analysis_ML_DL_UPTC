# %% [markdown]
# # STATEMENT

# %% [markdown]
# Suppose you are the CEO of a restaurant franchise and are considering different cities for opening a new outlet. The chain already has trucks in various cities and you have data for profits and populations from the cities. You'd like to figure out what the expected profit of a new food truck might be given only the population of the city that it would be placed in.

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("ex3_data.txt")

# %%
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
# Population    97 non-null float64
# Profit        97 non-null float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %% [markdown]
# ## DATA VISUALIZATION

# %%
plt.figure(figsize=(20,20))
sns.regplot(data["Population"],data["Profit"], color="Green")
plt.title("Profit vs Population")
# Out:
# Text(0.5, 1.0, 'Profit vs Population')

# %% [markdown]
# # SPLIT DATA

# %%
X = data[["Population"]]

# %%
y = data[["Profit"]]

# %%
X_train, x_test, Y_train ,y_test =  train_test_split(X,y)

# %% [markdown]
# # TRAIN DATA

# %%
regressor = LinearRegression()

# %%
regressor.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# # TESTING DATA

# %%
result = regressor.predict(x_test)

# %%
sns.distplot(result,hist=False,color="Red",label="Predicted Values")
sns.distplot(y_test,hist=False,color="Blue",label="Expected Values")
plt.xlabel("Population")
plt.ylabel("Profit")
plt.title("Predicted values vs Expected Values")
# Out:
# Text(0.5, 1.0, 'Predicted values vs Expected Values')

# %%
regressor.score(X,y)
# Out:
# 0.7020315537841397

# %%
plt.scatter(X_train, Y_train, color = 'orange')
plt.plot(X_train, regressor.predict(X_train), color = 'black')

# %%
regressor.predict([[25]])
# Out:
# array([[25.93006023]])
